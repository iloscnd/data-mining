# %% [markdown]
# # Lista 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Zadanie 1

# %%
a1 = np.random.uniform(-1,1,10000, density=True)

plt.hist(a1,100)
plt.plot(100)
plt.show()

a2 = np.random.uniform(-1,1,1000000, density=True)

plt.hist(a2,100)
plt.plot(100)
plt.show()
